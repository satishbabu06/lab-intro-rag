# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: #FF6347;">Self-Guided Lab: Retrieval-Augmented Generation (RAGs)</h1>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZ3FsdzRveTBrenMxM3VnbDMwaTJxN2NnZm50aGFibXk1NzNnY2Q0MCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/LR5ZBwZHv02lmpVoEU/giphy.gif" alt="NLP Gif" style="width: 300px; height: 150px; object-fit: cover; object-position: center;">
# </div>

# %% [markdown]
# <h1 style="color: #FF6347;">Data Storage & Retrieval</h1>

# %% [markdown]
# <h2 style="color: #FF8C00;">PyPDFLoader</h2>
#
# `PyPDFLoader` is a lightweight Python library designed to streamline the process of loading and parsing PDF documents for text processing tasks. It is particularly useful in Retrieval-Augmented Generation workflows where text extraction from PDFs is required.
#
# - **What Does PyPDFLoader Do?**
#   - Extracts text from PDF files, retaining formatting and layout.
#   - Simplifies the preprocessing of document-based datasets.
#   - Supports efficient and scalable loading of large PDF collections.
#
# - **Key Features:**
#   - Compatible with popular NLP libraries and frameworks.
#   - Handles multi-page PDFs and embedded images (e.g., OCR-compatible setups).
#   - Provides flexible configurations for structured text extraction.
#
# - **Use Cases:**
#   - Preparing PDF documents for retrieval-based systems in RAGs.
#   - Automating the text extraction pipeline for document analysis.
#   - Creating datasets from academic papers, technical manuals, and reports.

# %%
# %pip install langchain langchain_community pypdf
# %pip install termcolor langchain_openai langchain-huggingface sentence-transformers chromadb langchain_chroma tiktoken openai python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\user\appdata\roaming\python\python313\site-packages (1.3.0)
# Requirement already satisfied: langchain_community in c:\users\user\appdata\roaming\python\python313\site-packages (0.4.1)
# Requirement already satisfied: pypdf in c:\users\user\appdata\roaming\python\python313\site-packages (6.11.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain) (1.2.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\programdata\anaconda3\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.8.4)
# Requirement already satisfied: packaging>=23.2.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (4.1.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.0->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\programdata\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (0.24.0)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain_community) (1.0.7)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from langchain_community) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programdata\anaconda3\lib\site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain_community) (2.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: termcolor in c:\users\user\appdata\roaming\python\python313\site-packages (3.3.0)
# Requirement already satisfied: langchain_openai in c:\users\user\appdata\roaming\python\python313\site-packages (1.2.1)
# Requirement already satisfied: langchain-huggingface in c:\users\user\appdata\roaming\python\python313\site-packages (1.2.2)
# Requirement already satisfied: sentence-transformers in c:\users\user\appdata\roaming\python\python313\site-packages (5.5.0)
# Requirement already satisfied: chromadb in c:\users\user\appdata\roaming\python\python313\site-packages (1.5.9)
# Requirement already satisfied: langchain_chroma in c:\users\user\appdata\roaming\python\python313\site-packages (1.1.0)
# Requirement already satisfied: tiktoken in c:\users\user\appdata\roaming\python\python313\site-packages (0.13.0)
# Requirement already satisfied: openai in c:\users\user\appdata\roaming\python\python313\site-packages (2.36.0)
# Requirement already satisfied: python-dotenv in c:\programdata\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain_openai) (1.4.0)
# Requirement already satisfied: regex in c:\users\user\appdata\roaming\python\python313\site-packages (from tiktoken) (2026.5.9)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\programdata\anaconda3\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\programdata\anaconda3\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (0.8.4)
# Requirement already satisfied: packaging>=23.2.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain_openai) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\user\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain_openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain_openai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain_openai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain_openai) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-huggingface) (1.14.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: filelock>=3.10.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\user\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.0)
# Requirement already satisfied: typer>=0.20.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.25.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from sentence-transformers) (5.8.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from sentence-transformers) (2.12.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from sentence-transformers) (2.4.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\user\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\programdata\anaconda3\lib\site-packages (from chromadb) (2.12.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\user\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.47.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\programdata\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in c:\programdata\anaconda3\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\programdata\anaconda3\lib\site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\user\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\programdata\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\programdata\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\user\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\programdata\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in c:\users\user\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\user\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\programdata\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\user\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-proto==1.41.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b1 in c:\users\user\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->tiktoken) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools<82 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in c:\programdata\anaconda3\lib\site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\user\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\user\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\user\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter, RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h3 style="color: #FF8C00;">Loading the Documents</h3>

# %%
# File path for the document

file_path = "ai-for-everyone.pdf"

# %%
file_path = "../ai-for-everyone.pdf"

# %% [markdown]
# <h3 style="color: #FF8C00;">Documents into pages</h3>
#
# The `PyPDFLoader` library allows efficient loading and splitting of PDF documents into smaller, manageable parts for NLP tasks.
#
# This functionality is particularly useful in workflows requiring granular text processing, such as Retrieval-Augmented Generation (RAG).

# %%
# Load and split the document
loader = PyPDFLoader(file_path)
pages = loader.load_and_split()
len(pages)
# Out:
# 297

# %% [markdown]
# <h3 style="color: #FF8C00;">Pages into Chunks</h3>
#
#
# ####  RecursiveCharacterTextSplitter in LangChain
#
# The `RecursiveCharacterTextSplitter` is the **recommended splitter** in LangChain when you want to break down long documents into smaller, semantically meaningful chunks — especially useful in **RAG pipelines**, where clean context chunks lead to better LLM responses.
#
# ####  Parameters
#
# | Parameter       | Description                                                                 |
# |-----------------|-----------------------------------------------------------------------------|
# | `chunk_size`    | The **maximum number of characters** allowed in a chunk (e.g., `1000`).     |
# | `chunk_overlap` | The number of **overlapping characters** between consecutive chunks (e.g., `200`). This helps preserve context continuity. |
#
# ####  How it works
# `RecursiveCharacterTextSplitter` attempts to split the text **intelligently**, trying the following separators in order:
# 1. Paragraphs (`"\n\n"`)
# 2. Lines (`"\n"`)
# 3. Sentences or words (`" "`)
# 4. Individual characters (as a last resort)
#
# This makes it ideal for handling **natural language documents**, such as PDFs, articles, or long reports, without breaking sentences or paragraphs in awkward ways.

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
chunks = text_splitter.split_documents(pages)

len(chunks)
# Out:
# 1096

# %% [markdown]
# ####  Alternative: CharacterTextSplitter
#
# `CharacterTextSplitter` is a simpler splitter that breaks text into chunks based **purely on character count**, without trying to preserve any natural language structure.
#
# ##### Example:
# ```python
# from langchain.text_splitter import CharacterTextSplitter
#
# text_splitter = CharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )
# ````
#
# This method is faster and more predictable but may split text in the middle of a sentence or paragraph, which can hurt performance in downstream tasks like retrieval or QA.
#
# ---
#
# #### Comparison Table
#
# | Feature                        | RecursiveCharacterTextSplitter | CharacterTextSplitter     |
# | ------------------------------ | ------------------------------ | ------------------------- |
# | Structure-aware splitting      |  Yes                          |  No                      |
# | Preserves sentence/paragraphs  |  Yes                          |  No                      |
# | Risk of splitting mid-sentence |  Minimal                     |  High                   |
# | Ideal for RAG/document QA      |  Highly recommended           |  Only if structured text |
# | Performance speed              |  Slightly slower             |  Faster                  |
#
# ---
#
# #### Recommendation
#
# Use `RecursiveCharacterTextSplitter` for most real-world document processing tasks, especially when building RAG pipelines or working with structured natural language content like PDFs or articles.

# %% [markdown]
# ## Best Practices for Choosing Chunk Size in RAG
#
# ### Best Practices for Chunk Size in RAG
#
# | Factor                      | Recommendation                                                                                                                                                                                          |
# | ---------------------------| ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **LLM context limit**       | Choose a chunk size that lets you retrieve multiple chunks **without exceeding the model’s token limit**. For example, GPT-4o supports 128k tokens, but with GPT-3.5 (16k) or GPT-4 (32k), keep it modest. |
# | **Chunk size (in characters)** | Typically: **500–1,000 characters** per chunk → ~75–200 tokens. This fits well for retrieval + prompt without context overflow.                                                                           |
# | **Chunk size (in tokens)**  | If using token-based splitter (e.g. `TokenTextSplitter`): aim for **100–300 tokens** per chunk.                                                                                                            |
# | **Chunk overlap**           | Use **overlap of 10–30%** (e.g., 100–300 characters or ~50 tokens) to preserve context across chunk boundaries and avoid cutting off important ideas mid-sentence.                                        |
# | **Document structure**      | Use **`RecursiveCharacterTextSplitter`** to preserve semantic boundaries (paragraphs, sentences) instead of arbitrary cuts.                                                                                |
# | **Task type**               | For **question answering**, smaller chunks (~500–800 chars) reduce noise.<br>For **summarization**, slightly larger chunks (~1000–1500) are OK.                                                          |
# | **Embedding model**         | Some models (e.g., `text-embedding-3-large`) can handle long input. But still, smaller chunks give **finer-grained retrieval**, which improves relevance.                                                  |
# | **Query type**              | If users ask **very specific questions**, small focused chunks are better. For broader queries, bigger chunks might help.                                                                                  |
#
#
# ### Rule of Thumb
#
# | Use Case                 | Chunk Size      | Overlap |
# | ------------------------| --------------- | ------- |
# | Factual Q&A              | 500–800 chars   | 100–200 |
# | Summarization            | 1000–1500 chars | 200–300 |
# | Technical documents      | 400–700 chars   | 100–200 |
# | Long reports/books       | 800–1200 chars  | 200–300 |
# | Small LLMs (≤16k tokens) | ≤800 chars      | 100–200 |
#
#
# ### Avoid
#
# - Chunks >2000 characters: risks context overflow.
# - No overlap: may lose key information between chunks.

# %% [markdown]
# <h2 style="color: #FF8C00;">Embeddings</h2>
#
# Embeddings transform text into dense vector representations, capturing semantic meaning and contextual relationships. They are essential for efficient document retrieval and similarity analysis.
#
# - **What are OpenAI Embeddings?**
#   - Pre-trained embeddings like `text-embedding-3-large` generate high-quality vector representations for text.
#   - Encapsulate semantic relationships in the text, enabling robust NLP applications.
#
# - **Key Features of `text-embedding-3-large`:**
#   - Large-scale embedding model optimized for accuracy and versatility.
#   - Handles diverse NLP tasks, including retrieval, classification, and clustering.
#   - Ideal for applications with high-performance requirements.
#
# - **Benefits:**
#   - Reduces the need for extensive custom training.
#   - Provides state-of-the-art performance in retrieval-augmented systems.
#   - Compatible with RAGs to create powerful context-aware models.

# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv,find_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %% [markdown]
# <h2 style="color: #FF8C00;">ChromaDB</h2>
#
# ChromaDB is a versatile vector database designed for efficiently storing and retrieving embeddings. It integrates seamlessly with embedding models to enable high-performance similarity search and context-based retrieval.
#
# ### Workflow Overview:
# - **Step 1:** Generate embeddings using a pre-trained model (e.g., OpenAI's `text-embedding-3-large`).
# - **Step 2:** Store the embeddings in ChromaDB for efficient retrieval and similarity calculations.
# - **Step 3:** Use the stored embeddings to perform searches, matching, or context-based retrieval.
#
# ### Key Features of ChromaDB:
# - **Scalability:** Handles large-scale datasets with optimized indexing and search capabilities.
# - **Speed:** Provides fast and accurate retrieval of embeddings for real-time applications.
# - **Integration:** Supports integration with popular frameworks and libraries for embedding generation.

# %%
from langchain_chroma import Chroma

# %%
db = Chroma.from_documents(chunks, embeddings, persist_directory="./chroma_db_LAB")
print("ChromaDB created with document embeddings.")
# Out:
# ChromaDB created with document embeddings.

# %% [markdown]
# <h1 style="color: #FF6347;">Retrieving Documents</h1>

# %% [markdown]
# ### Exercice1: Write a user question that someone might ask about your book’s topic or content.

# %%
user_question = "What does it mean for AI to be accessible, representative, and beneficial to everyone, and what power dynamics stand in the way?" # User question
retrieved_docs = db.similarity_search(user_question, k=10) # k is the number of documents to retrieve

# %%
# Display top results
for i, doc in enumerate(retrieved_docs[:3]): # Display top 3 results
    print(f"Document {i+1}:\n{doc.page_content[36:1000]}") # Display content
# Out:
# Document 1:
# ord 2018). Questions about inclusion and representation are
# inherently political questions. AI also refers to industrial infrastructures: the
# infrastructure does not only entail the possibilities of collecting vast amounts
# of data, but also the computational power needed to develop machine/deep
# learning models. Very few companies have simultaneously the computational
# power, access to data and AI expertise (human resources) at their disposal,
# which means that the economic power of these organisations is crucial for the
# development of AI and is highly concentrated (Dyer-Witheford, Kjøsen and
# Steinhoff 2019).
# The Case for a Radical Democratisation of AI
# Asking critical questions about AI with the objective to foster human eman -
# cipation requires us to investigate the political and economic power dynam -
# ics of AI. My point here is that we need to move beyond discussions of what
# Document 2:
#  full of examples of how technology is being developed by (pre-
# dominantly) white middle-class men, thereby excluding people of colour and
# minority communities. Wright (2019) also connects democracy and freedom
# in order to reflect the value of self-determination. In this sense, members of
# society should be given the possibility to participate meaningfully in decisions
# that affect their lives. As AI becomes more omnipresent, people should have
# a say about this. Principles such as fairness, accountability and transparency
# (ACM 2020) are key when we want technological development not only to
# represent the people but also guaranteeing control by the people to counterbal-
# ance the power of the state and corporations.
# #Principle 3: AI Should Be Beneficial to Everyone
# The third and last principle states that developments in AI should contribute
# to the well-being of everyone in society. This matches with Wright’s (2019)
# Document 3:
# rious about making sure that AI will benefit
# everyone, we need to talk about power. Power refers to the capacity to influ -
# ence the actions, beliefs or behaviour of others. Ultimately, this comes down
# to ‘the question of who can influence what society looks like and who controls
# the means that allow such influence’ (Fuchs 2017: 86). Power decides who will
# benefit from new technologies such as AI, but a concentration of power
# will likely result in growing inequalities and other negative outcomes. The
# current critiques about AI centre on AI ethics (Coeckelbergh 2020), which is
# valuable and important to shape policy discussions. AI ethics, however, also
# has serious limitations when it comes to bringing about real change and mak -
# ing sure that the benefits of AI are accessible for everyone. Further in this intro-
# duction, I elaborate on this and I make the case for a radical democratisation of

# %% [markdown]
# <h2 style="color: #FF8C00;">Preparing Content for GenAI</h2>

# %%
def _get_document_prompt(docs):
    prompt = "\n"
    for doc in docs:
        prompt += "\nContent:\n"
        prompt += doc.page_content + "\n\n"
    return prompt

# %%
# Generate a formatted context from the retrieved documents
formatted_context = _get_document_prompt(retrieved_docs)
print("Context formatted for GPT model.")
# Out:
# Context formatted for GPT model.

# %% [markdown]
# <h2 style="color: #FF8C00;">ChatBot Architecture</h2>

# %% [markdown]
# ### Exercice2: Write a prompt that is relevant and tailored to the content and style of your book.

# %%
prompt = f"""
You are an expert assistant on critical AI studies, helping readers engage with the book *AI for Everyone? Critical Perspectives* edited by Pieter Verdegem.

Use the context below — excerpts retrieved directly from the book — to answer the user's question in a thoughtful, academically grounded way. 
Reference specific arguments or authors from the text where relevant. If the context does not contain enough information, say so clearly.

Retrieved context:
{formatted_context}

User question: {user_question}

Provide a well-structured answer (3–5 paragraphs) that:
- Summarises the book's core argument about AI democratisation
- Identifies the three key principles (accessible, representative, beneficial)
- Discusses the power and inequality challenges raised by the authors
- Uses an objective, critical academic tone

"""

# %%
import openai

# %% [markdown]
# ### Exercice3: Tune parameters like temperature, and penalties to control how creative, focused, or varied the model's responses are.

# %%
# Set up GPT client and parameters
client = openai.OpenAI()
model_params = {
    'model': 'gpt-4o-mini',
    'temperature': 0.7,  # Increase creativity
    'max_tokens': 500,  # Allow for longer responses
    'top_p': 1.0,        # Use nucleus sampling
    'frequency_penalty': 0.0,  # Reduce repetition
    'presence_penalty': 0.0   # Encourage new topics
}

# %% [markdown]
# <h1 style="color: #FF6347;">Response</h1>

# %%
messages = [{'role': 'user', 'content': prompt}]
completion = client.chat.completions.create(messages=messages, **model_params, timeout=120)

# %%
answer = completion.choices[0].message.content
print(answer)
# Out:
# The book *AI for Everyone? Critical Perspectives* edited by Pieter Verdegem addresses the urgent need for a more inclusive approach to artificial intelligence (AI) through the lens of democratisation. The core argument posits that as AI technologies proliferate, it is imperative that their development and application not only serve a select few but are instead accessible, representative, and beneficial to all segments of society. This perspective challenges the prevailing notion of AI as a utility akin to electricity, which has been touted as universally available and beneficial, by revealing the underlying complexities and inequities that often accompany AI integration into daily life.
#
# To understand the implications of AI democratisation, it is essential to define the three key principles: accessibility, representation, and benefit. Accessibility refers to the ease with which diverse populations can engage with AI technologies, including access to the necessary resources and education to utilise these systems effectively. Representation emphasizes the need for AI systems to reflect the diversity of the user base, ensuring that various societal groups are included in the design, development, and deployment processes. Finally, the principle of benefit underscores that AI should enhance the quality of life for everyone, addressing societal issues rather than exacerbating existing inequalities.
#
# However, the authors of the book highlight significant power dynamics that impede the realisation of these principles. One major challenge is the concentration of technological power in the hands of a few dominant tech giants, which can lead to a homogenisation of AI applications that may not consider the needs and perspectives of marginalized communities. This concentration creates barriers to entry for smaller players and limits the diversity of voices in AI development. Furthermore, the risk of algorithmic bias, which can arise from training data that lacks diversity, poses a threat to representation and equity. When AI systems are built on skewed datasets, they may perpetuate stereotypes and reinforce existing social inequities, thus failing to serve the broader population.
#
# In conclusion, while the vision of democratised AI holds promise for creating a more equitable technological landscape, it is fraught with challenges stemming from entrenched power dynamics and systemic inequalities. The call for AI to be accessible, representative, and beneficial for all necessitates a concerted effort to address these barriers. This can include regulatory measures to ensure fair competition, initiatives to diversify the tech workforce, and ongoing scrutiny of AI systems to mitigate bias. Ultimately, the path toward a truly democratic AI landscape will require collaboration among stakeholders, including policymakers, technologists, and civil society, to foster an environment where AI can genuinely serve the interests of

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:824/1*GK56xmDIWtNQAD_jnBIt2g.png" alt="NLP Gif" style="width: 500px">

# %% [markdown]
# <h2 style="color: #FF6347;">Cosine Similarity</h2>
#
# **Cosine similarity** is a metric used to measure the alignment or similarity between two vectors, calculated as the cosine of the angle between them. It is the **most common metric used in RAG pipelines** for vector retrieval.. It provides a scale from -1 to 1:
#
# - **-1**: Vectors are completely opposite.
# - **0**: Vectors are orthogonal (uncorrelated or unrelated).
# - **1**: Vectors are identical.

# %% [markdown]
# <img src="https://storage.googleapis.com/lds-media/images/cosine-similarity-vectors.original.jpg" alt="NLP Gif" style="width: 700px">

# %% [markdown]
# <h2 style="color: #FF6347;">Keyword Highlighting</h2>
#
# Highlighting important keywords helps users quickly understand the relevance of the retrieved text to their query.

# %%
from termcolor import colored

# %% [markdown]
# The `highlight_keywords` function is designed to highlight specific keywords within a given text. It replaces each keyword in the text with a highlighted version using the `colored` function from the `termcolor` library.

# %%
def highlight_keywords(text, keywords):
    for keyword in keywords:
        text = text.replace(keyword, colored(keyword, 'green', attrs=['bold']))
    return text

# %% [markdown]
# ### Exercice4: add your keywords

# %%
query_keywords = [    "democratisation",
    "power",
    "inequality",
    "accessible",
    "representative",
    "beneficial",
    "algorithmic",
    "fairness",
    "data",
    "inclusion"] # add your keywords
for i, doc in enumerate(retrieved_docs[:1]):
    snippet = doc.page_content[:200]
    highlighted = highlight_keywords(snippet, query_keywords)
    print(f"Snippet {i+1}:\n{highlighted}\n{'-'*80}")
# Out:
# Snippet 1:
# 12 AI for Everyone?
# look like (Crawford 2018). Questions about inclusion and representation are
# inherently political questions. AI also refers to industrial infrastructures: the
# infrastructure does
# --------------------------------------------------------------------------------

# %% [markdown]
# 1. `query_keywords` is a list of keywords to be highlighted.
# 2. The loop iterates over the first document in retrieved_docs.
# 3. For each document, a snippet of the first 200 characters is extracted.
# 4. The highlight_keywords function is called to highlight the keywords in the snippet.
# 5. The highlighted snippet is printed along with a separator line.

# %% [markdown]
# <h1 style="color: #FF6347;">Bonus</h1>

# %% [markdown]
# **Try loading one of your own PDF books and go through the steps again to explore how the pipeline works with your content**:
